# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("train (3).csv")

# %%
pd.DataFrame(df)
# Out:
#      State_Code  Account_Length_Months  Area_Code  Intl_Plan  VM_Plan  \
# 0            MI                     36        510          0        0
# 1            TN                     16        510          0        0
# 2            DC                     99        415          0        0
# 3            WY                    159        510          0        0
# 4            NJ                     77        510          0        0
# ...         ...                    ...        ...        ...      ...
# 3462         VA                    117        415          0        1
# 3463         MI                    110        415          1        0
# 3464         IN                    136        415          0        1
# 3465         KY                     93        415          0        1
# 3466         WA                    158        510          0        0
#
#       VM_Messages  Avg_Day_Minutes  Avg_Day_Calls  Avg_Day_Charge  \
# ...
